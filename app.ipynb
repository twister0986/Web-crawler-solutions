# %%
from bs4 import BeautifulSoup
import Dynamic_crawler

selenium_driver=Dynamic_crawler.selenium_bulid()
print(type(selenium_driver))
# Out:
# <class 'selenium.webdriver.chrome.webdriver.WebDriver'>
